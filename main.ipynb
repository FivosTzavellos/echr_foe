# %%
import fire
from ipynb.fs.full.codebase.logging_config import setup_logging

logger = setup_logging()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 import fire
#       2 from ipynb.fs.full.codebase.logging_config import setup_logging
# ----> 4 logger = setup_logging()
#
# File ~/Law_and_Tech/ECHR_FOE/echr_foe/codebase/logging_config.ipynb:47, in setup_logging()
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "metadata": {},
#       7    "outputs": [],
#       8    "source": [
#       9     "import logging\n",
#      10     "import os\n",
#      11     "from dotenv import load_dotenv\n",
#      12     "from pathlib import Path"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 2,
#      18    "metadata": {},
#      19    "outputs": [],
#      20    "source": [
# ...
